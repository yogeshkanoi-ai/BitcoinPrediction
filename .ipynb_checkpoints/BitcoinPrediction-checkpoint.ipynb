# %%
import pandas as pd
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('/home/user/Documents/My ML Projects/BitcoinPrediction/BTC-USD.csv')
df = df[["Date", "Close"]]
df.columns = ["ds", "y"]
df
# Out:
#              ds             y
# 0    2020-03-04   8755.246094
# 1    2020-03-05   9078.762695
# 2    2020-03-06   9122.545898
# 3    2020-03-07   8909.954102
# 4    2020-03-08   8108.116211
# ..          ...           ...
# 361  2021-02-28  45137.769531
# 362  2021-03-01  49631.242188
# 363  2021-03-02  48378.988281
# 364  2021-03-03  50538.242188
# 365  2021-03-04  49647.800781
#
# [366 rows x 2 columns]

# %%
prophet = Prophet()
prophet.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = prophet.make_future_dataframe(periods=365)
print(future)
# Out:
#             ds
# 0   2020-03-04
# 1   2020-03-05
# 2   2020-03-06
# 3   2020-03-07
# 4   2020-03-08
# ..         ...
# 726 2022-02-28
# 727 2022-03-01
# 728 2022-03-02
# 729 2022-03-03
# 730 2022-03-04
#
# [731 rows x 1 columns]

# %%
forecast = prophet.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(200)
# Out:
#             ds           yhat     yhat_lower     yhat_upper
# 531 2021-08-17  112624.292567  104741.177150  120630.301546
# 532 2021-08-18  113221.797219  104703.593044  121415.550313
# 533 2021-08-19  113492.378993  104907.060544  121768.295800
# 534 2021-08-20  113991.419862  105241.468849  122466.715096
# 535 2021-08-21  114314.643484  105935.114769  122729.143068
# ..         ...            ...            ...            ...
# 726 2022-02-28  184525.115706  158137.708997  210037.964227
# 727 2022-03-01  184736.614885  158585.436082  210923.294502
# 728 2022-03-02  185334.119537  158492.909143  211335.323057
# 729 2022-03-03  185604.701311  159142.524067  211657.351680
# 730 2022-03-04  186103.742180  160601.553107  211912.406847
#
# [200 rows x 4 columns]

# %%
from fbprophet.plot import plot
prophet.plot(forecast, figsize=(20, 10))
